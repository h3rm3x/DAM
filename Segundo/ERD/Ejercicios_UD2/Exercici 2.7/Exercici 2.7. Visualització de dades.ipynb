# %% [markdown]
# # Exercici 2.7. Anàlisi de dades d’una plataforma d’e-learning

# %% [markdown]
# En aquesta activitat treballarem amb tres fitxers CSV que contenen informació sobre cursos, estudiants i activitats completes dins d’una plataforma educativa en línia.
#
# Els fitxers són:
#
# courses.csv — informació sobre els cursos disponibles
#
# students.csv — dades dels estudiants registrats
#
# progress.csv — registres de visualització i progrés dels estudiants

# %% [markdown]
# 1. Importa les llibreries necessàries
#
# Carrega:
#
# pandas com pd
#
# numpy com np
#
# matplotlib.pyplot com plt
#
# seaborn com sns

# %% [markdown]
# 2. Carrega els fitxers CSV
#
# Llegeix:
#
# courses.csv
#
# students.csv
#
# progress.csv
#
# Mostra les primeres 5 files de cada DataFrame per familiaritzar-te amb les dades.

# %%
# Out:
# === courses.head() ===
#    course_id course_title   category    difficulty  num_lessons publish_date
# 0          1     Course 1  Languages  Intermediate           16   2023-10-23
# 1          2     Course 2   Business  Intermediate           30   2023-10-19
# 2          3     Course 3     Design      Beginner           18   2022-07-20
# 3          4     Course 4   Business      Beginner           48   2024-02-04
# 4          5     Course 5   Business      Beginner           27   2022-12-04
#
# === students.head() ===
#    student_id          name  age       city registration_date
# 0        1000  Student 1000   41    Alacant        2022-09-25
# 1        1001  Student 1001   40  Barcelona        2023-07-31
# 2        1002  Student 1002   60   Valencia        2023-02-21
# 3        1003  Student 1003   56  Barcelona        2022-06-17
# 4        1004  Student 1004   44    Alacant        2022-02-12
#
# === progress.head() ===
# ...

# %% [markdown]
# 3. Uneix les dades en un sol DataFrame
#
# Crea un DataFrame anomenat learning_df que continga:
#
# progress JOIN courses utilitzant course_id
#
# després, JOIN amb students utilitzant student_id
#
# Mostra:
#
# el nombre de files i columnes (shape)
#
# informació general (info())

# %%
# Out:
# Learning_df shape: (5000, 16)
#
# Learning_df info():
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   progress_id        5000 non-null   int64
#  1   student_id         5000 non-null   int64
#  2   course_id          5000 non-null   int64
#  3   lesson_number      5000 non-null   int64
#  4   minutes_watched    5000 non-null   float64
#  5   completed          5000 non-null   int64
#  6   progress_date      5000 non-null   object
#  7   course_title       5000 non-null   object
#  8   category           5000 non-null   object
#  9   difficulty         5000 non-null   object
#  10  num_lessons        5000 non-null   int64
#  11  publish_date       5000 non-null   object
#  12  name               5000 non-null   object
#  13  age                5000 non-null   int64
#  14  city               5000 non-null   object
# ...

# %% [markdown]
# 4. Calcula el temps total d’estudi
#
# Suposem que en el fitxer progress.csv hi ha:
#
# minutes_watched → minuts visualitzats per l’estudiant
#
# completed → 1 si la lliçó està completada, 0 en cas contrari
#
# Afegeix una columna: hours_watched = minutes_watched / 60
#
# Mostra les 10 primeres files després de calcular-la.

# %%
# Out:
# === Primeres 10 files amb hours_watched ===
#    progress_id  student_id  course_id  lesson_number  minutes_watched  \
# 0            1        1015          9             13        24.711408
# 1            2        1199         15             13         1.194032
# 2            3        1101          1             15        11.499747
# 3            4        1151         12             14         7.145068
# 4            5        1155          3              8         3.877441
# 5            6        1116         11             11        22.876368
# 6            7        1007          2             18        24.951090
# 7            8        1121         16             36         5.334309
# 8            9        1091          9             10         1.922401
# 9           10        1163         15              1         7.601307
#
#    completed        progress_date course_title      category    difficulty  \
# 0          0  2023-01-22 14:36:00     Course 9        Design  Intermediate
# ...

# %% [markdown]
# 5. Visualització 1 — Distribució de l’edat dels estudiants
#
# Utilitza seaborn.histplot() per mostrar la distribució de les edats.
#
# Inclou:
#
# títol
#
# etiquetes dels eixos
#
# un color suau

# %% [markdown]
# 6. Visualització 2 — Temps total d’estudi per categoria de curs
#
# Agrupa per category i calcula el total d’hores visualitzades.
#
# Representa un gràfic de barres.
#
# Requisits:
#
# ordenar les categories de més a menys temps d’estudi
#
# utilitzar una paleta de colors
#
# mostrar el valor damunt de cada barra

# %%
# Out:
# C:\Users\ciclesgs\AppData\Local\Temp\ipykernel_2152\773896324.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=hours_by_category, y="category", x="total_hours", palette="viridis")

# %% [markdown]
# 7. Visualització 3 — Evolució mensual del consum de contingut
#
# Converteix progress_date a datetime si cal.
#
# Agrupa per mes utilitzant: learning_df.resample('M', on='progress_date')['hours_watched'].sum()
#
# Representa un gràfic de línia per mostrar l’evolució temporal.

# %%
# Out:
# C:\Users\ciclesgs\AppData\Local\Temp\ipykernel_2152\3408992039.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly = learning_df.resample("M", on="progress_date")["hours_watched"].sum().rename("monthly_hours")

# %% [markdown]
# 8. Visualització 4 — Comparació del temps d’estudi per cursos
#
# Representa un boxplot que mostre la distribució d’hores vistes per curs.
#
# Opcional: filtrar els cursos amb més activitat per evitar gràfics molt llargs.

# %% [markdown]
# 9. Anàlisi de correlació (has d'instal·lar pip install scipy)
#
# Analitza la relació entre:
#
# el nombre total de lliçons completades per estudiant
#
# les hores totals visualitzades
#
# Passos:
#
# Agrupa per estudiant i calcula:
#
# lessons_completed
#
# total_hours_watched
#
# Crea un scatterplot amb línia de regressió (sns.regplot())

# %%
# Out:
# Correlació Pearson: 0.590
# Correlació Spearman: 0.568

# %% [markdown]
# 10. Calcula:
#
# percentatge mitjà de completitud de cada curs
#
# rànquing dels cursos més “difícils” (menor percentatge de finalització)
#
# rànquing dels cursos més “consumits” (més hores vistes)

# %%
# Out:
# Percentatge de completitud per curs (ordenat ascendent):
#    course_title  completion_rate
# 17    Course 18        24.242424
# 10    Course 11        24.590164
# 7      Course 8        25.000000
# 14    Course 15        26.104418
# 1      Course 2        28.286853
# 18    Course 19        28.451883
# 8      Course 9        28.688525
# 11    Course 12        29.296875
# 19    Course 20        30.081301
# 4      Course 5        30.416667
# 3      Course 4        30.543933
# 15    Course 16        30.685921
# 16    Course 17        30.740741
# 9     Course 10        30.970149
# 12    Course 13        31.481481
# 0      Course 1        31.496063
# 13    Course 14        31.914894
# 5      Course 6        31.950207
# 2      Course 3        32.773109
# 6      Course 7        32.818533
#
# Cursos més difícils (menor completitud):
#    course_title  completion_rate
# 17    Course 18        24.242424
# 10    Course 11        24.590164
# 7      Course 8        25.000000
# ...
