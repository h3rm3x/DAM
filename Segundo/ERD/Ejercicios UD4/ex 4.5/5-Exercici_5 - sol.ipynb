# %% [markdown]
# # Predicción de cancelación de reservas hoteleras

# %% [markdown]
# 1. Importar librerías

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# 2. Cargar datos

# %%
df = pd.read_csv("hotel_reservas_knn.csv")
df.head()
# Out:
#    dias_anticipacion  noches_estancia  precio_noche  num_huespedes  \
# 0                102               12    147.884114              2
# 1                348                6    167.298153              2
# 2                270               12    143.380129              3
# 3                106               11    137.986236              4
# 4                 71               13     89.317820              4
#
#    historico_cancelaciones  CANCELA
# 0                        1        0
# 1                        0        1
# 2                        1        1
# 3                        0        0
# 4                        2        1

# %% [markdown]
# 3. EDA

# %%
df.describe()
sns.pairplot(df, hue="CANCELA")

# %% [markdown]
# 4. Escalar variables

# %%
from sklearn.preprocessing import StandardScaler

X = df.drop("CANCELA", axis=1)
y = df["CANCELA"]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# 5. Train/Test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.3, random_state=42
)

# %% [markdown]
# 6. Modelo KNN inicial

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# 7. Evaluación

# %%
from sklearn.metrics import classification_report, confusion_matrix

pred = knn.predict(X_test)
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# [[316  76]
#  [113  95]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.81      0.77       392
#            1       0.56      0.46      0.50       208
#
#     accuracy                           0.69       600
#    macro avg       0.65      0.63      0.64       600
# weighted avg       0.67      0.69      0.68       600

# %% [markdown]
# 8. Método del codo (error rate)

# %%
error_rate = []

for k in range(1, 40):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    pred_k = knn.predict(X_test)
    error_rate.append(np.mean(pred_k != y_test))

plt.plot(range(1,40), error_rate, marker='o')
plt.title("Selección de K")
plt.show()
