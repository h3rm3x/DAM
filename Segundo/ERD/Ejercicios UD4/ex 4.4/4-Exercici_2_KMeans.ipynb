# %% [markdown]
# # Segmentación de pacientes para gestión hospitalaria (NO diagnóstico)

# %% [markdown]
# Contexto real
#
# Un hospital quiere segmentar pacientes para:
#
# Optimizar recursos
#
# Prever carga asistencial
#
# Diseñar programas de prevención
#
# ⚠️ No se diagnostica nada → uso operativo, no clínico.

# %% [markdown]
# Variables del dataset
#
# edad
#
# visitas_anuales
#
# gasto_anual
#
# num_pruebas
#
# dias_ingreso_total
#
# medicacion_cronica (0–1)

# %% [markdown]
# Carga de librerías y datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv('pacientes_kmeans_project.csv')
df.head()
# Out:
#    edad  visitas_anuales  gasto_anual  num_pruebas  dias_ingreso_total  \
# 0    69                4  1336.266652            1                   0
# 1    32                8   936.583087            1                   2
# 2    89                2   643.655596            4                   3
# 3    78                1  2008.660534            5                   1
# 4    38                6   456.750504            5                   4
#
#    medicacion_cronica
# 0                   1
# 1                   0
# 2                   0
# 3                   1
# 4                   1

# %% [markdown]
# Análisis exploratorio

# %%
sns.pairplot(df)

# %% [markdown]
# Escalado

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)
scaled_df = pd.DataFrame(scaled_data, columns=df.columns)
scaled_df.head()
# Out:
#        edad  visitas_anuales  gasto_anual  num_pruebas  dias_ingreso_total  \
# 0  0.773579         0.039999     0.080096    -1.100865           -1.414833
# 1 -1.000978         2.145197    -0.388646    -1.100865           -0.063512
# 2  1.732799        -1.012600    -0.732186     0.555955            0.612149
# 3  1.205228        -1.538900     0.868669     1.108229           -0.739173
# 4 -0.713212         1.092598    -0.951385     1.108229            1.287809
#
#    medicacion_cronica
# 0            1.143544
# 1           -0.874475
# 2           -0.874475
# 3            1.143544
# 4            1.143544

# %% [markdown]
# Método del codo

# %%
from sklearn.cluster import KMeans

inertia = []

for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(scaled_df)
    inertia.append(kmeans.inertia_)
    
plt.plot(range(1, 11), inertia, marker='o')
plt.xlabel('Número de clusters (k)')
plt.ylabel('Inercia')
plt.title('Método del codo para determinar k óptimo')
# Out:
# Text(0.5, 1.0, 'Método del codo para determinar k óptimo')

# %% [markdown]
# Modelo final

# %%
kmeans = KMeans(n_clusters=4, random_state=42)
kmeans.fit(scaled_df)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %% [markdown]
# Perfilado de pacientes

# %%
df['Cluster'] = kmeans.labels_
df.groupby('Cluster').mean()
# Out:
#               edad  visitas_anuales  gasto_anual  num_pruebas  \
# Cluster
# 0        71.220859         3.601227  1385.767384     2.717791
# 1        35.694444         4.163580  1224.261836     3.283951
# 2        67.068650         4.398169  1187.132098     3.242563
# 3        36.837772         3.489104  1294.813911     2.719128
#
#          dias_ingreso_total  medicacion_cronica
# Cluster
# 0                  1.984663            0.996933
# 1                  2.222222            1.000000
# 2                  2.663616            0.002288
# 3                  1.476998            0.000000

# %% [markdown]
# Interpretación típica:

# %%
# cluster 0: pacientes mayores medicacion cronica, gasto alto y pocos ingresos
# cluster 1: pacientes jovenes con medicacion cronica, gasto bajo y muchas visitas
# cluster 2: pacientes mayores sin medicacion cronica, gasto bajo y muchas visitas
# cluster 3: pacientes jovenes sin medicacion cronica, gasto muy bajo, pocos ingresos y pocas visitas

# %%
plt.figure()
sns.scatterplot(data=df, x='gasto_anual', y='edad', hue='Cluster', palette='Set1')
plt.title('Clusters de pacientes según gasto anual y edad')
plt.show()
