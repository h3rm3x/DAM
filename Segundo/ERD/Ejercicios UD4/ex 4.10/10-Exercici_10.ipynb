# %% [markdown]
# # Detección de impago en microcréditos

# %% [markdown]
# Importar librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score, roc_curve
sns.set(style="whitegrid")

# %% [markdown]
# Cargar datos

# %%
# Cargar datos

df = pd.read_csv('vino_knn.csv')
df.head()
# Out:
#      acidez    azucar        pH    alcohol    sulfitos  ALTA_CALIDAD
# 0  6.889237  4.904982  2.977645  10.925158  127.738786             0
# 1  7.483457  2.611606  3.296569  10.925641   83.315873             0
# 2  5.373226  3.923869  3.727853  11.764781   47.474915             0
# 3  8.033454  2.584726  3.488425  10.562188  142.306949             0
# 4  5.726187  3.104907  3.094014  13.524677   82.517178             1

# %% [markdown]
# EDA

# %%
# EDA

df.info()

df.describe().T

print('Valores nulos:\n', df.isnull().sum())
print('\nDistribución ALTA_CALIDAD:\n', df['ALTA_CALIDAD'].value_counts())

plt.figure(figsize=(6,5))
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlación entre variables')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   acidez        2000 non-null   float64
#  1   azucar        2000 non-null   float64
#  2   pH            2000 non-null   float64
#  3   alcohol       2000 non-null   float64
#  4   sulfitos      2000 non-null   float64
#  5   ALTA_CALIDAD  2000 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 93.9 KB
# Valores nulos:
#  acidez          0
# azucar          0
# pH              0
# alcohol         0
# sulfitos        0
# ALTA_CALIDAD    0
# dtype: int64
#
# Distribución ALTA_CALIDAD:
#  ALTA_CALIDAD
# 0    1638
# 1     362
# Name: count, dtype: int64

# %% [markdown]
# Separar variables

# %%
# Separar variables

X = df.drop('ALTA_CALIDAD', axis=1)
y = df['ALTA_CALIDAD']
X.head()
# Out:
#      acidez    azucar        pH    alcohol    sulfitos
# 0  6.889237  4.904982  2.977645  10.925158  127.738786
# 1  7.483457  2.611606  3.296569  10.925641   83.315873
# 2  5.373226  3.923869  3.727853  11.764781   47.474915
# 3  8.033454  2.584726  3.488425  10.562188  142.306949
# 4  5.726187  3.104907  3.094014  13.524677   82.517178

# %% [markdown]
# Escalar

# %%
# Escalar

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)
X_scaled.head()
# Out:
#      acidez    azucar        pH   alcohol  sulfitos
# 0  0.744790  1.914645 -1.555929 -0.709735  0.909872
# 1  1.246506 -0.400737  0.000512 -0.709419 -0.570512
# 2 -0.535219  0.924118  2.105301 -0.160255 -1.764904
# 3  1.710884 -0.427874  0.936826 -0.947276  1.395353
# 4 -0.237205  0.097297 -0.988011  0.991485 -0.597128

# %% [markdown]
# Train/Test split

# %%
# Train/Test split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42, stratify=y)
X_train.shape, X_test.shape
# Out:
# ((1400, 5), (600, 5))

# %% [markdown]
# Modelo inicial

# %%
# Modelo inicial

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

# %% [markdown]
# Perfil de usuarios

# %%
# Perfil por clase

display(df.groupby('ALTA_CALIDAD').mean())
display(df.groupby('ALTA_CALIDAD').size())
# Out:
#                 acidez    azucar        pH    alcohol    sulfitos
# ALTA_CALIDAD
# 0             6.006578  3.009954  3.271944  11.787795  100.386235
# 1             6.009606  3.002108  3.407412  13.013545  100.659114
# ALTA_CALIDAD
# 0    1638
# 1     362
# dtype: int64

# %% [markdown]
# Evaluación

# %%
# Evaluación

acc = accuracy_score(y_test, y_pred)
print(f'Accuracy: {acc:.4f}')
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicho')
plt.ylabel('Real')
plt.title('Matriz de confusión')
plt.show()

print(classification_report(y_test, y_pred))

if len(np.unique(y_test))==2:
    y_proba = knn.predict_proba(X_test)[:,1]
    print('ROC AUC:', roc_auc_score(y_test, y_proba))
    fpr,tpr,_ = roc_curve(y_test, y_proba)
    plt.figure(figsize=(6,4))
    plt.plot(fpr,tpr)
    plt.plot([0,1],[0,1],'k--')
    plt.xlabel('FPR')
    plt.ylabel('TPR')
    plt.title('ROC Curve')
    plt.show()
# Out:
# Accuracy: 0.8050
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89       491
#            1       0.44      0.26      0.32       109
#
#     accuracy                           0.81       600
#    macro avg       0.64      0.59      0.60       600
# weighted avg       0.77      0.81      0.78       600
#
# ROC AUC: 0.7568246790859321

# %% [markdown]
# Elegir K óptimo

# %%
# Elegir K óptimo

error_rate = []
ks = range(1,21)
for k in ks:
    knn_k = KNeighborsClassifier(n_neighbors=k)
    knn_k.fit(X_train, y_train)
    pred_k = knn_k.predict(X_test)
    error_rate.append(np.mean(pred_k != y_test))

plt.figure(figsize=(8,4))
plt.plot(ks, error_rate, marker='o')
plt.xlabel('k')
plt.ylabel('Tasa de error')
plt.title('Error rate vs k')
plt.xticks(ks)
plt.show()

best_k = ks[int(np.argmin(error_rate))]
print('Mejor k por menor error:', best_k)
# Out:
# Mejor k por menor error: 13

# %% [markdown]
# # Reentrenamiento con el mejor K
#
# **Reentrena tu modelo con el mejor valor de K y evalúa su rendimiento.**

# %%
# Reentrenar con el mejor k
print(f'Reentrenando con K={best_k}')

knn = KNeighborsClassifier(n_neighbors=best_k)
knn.fit(X_train, y_train)
y_pred_final = knn.predict(X_test)

# Evaluación del modelo final
print(f'\nCon K={best_k}')
print('\n')
print(confusion_matrix(y_test, y_pred_final))
print('\n')
print(classification_report(y_test, y_pred_final))
# Out:
# Reentrenando con K=13
#
# Con K=13
#
#
# [[478  13]
#  [ 95  14]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.97      0.90       491
#            1       0.52      0.13      0.21       109
#
#     accuracy                           0.82       600
#    macro avg       0.68      0.55      0.55       600
# weighted avg       0.78      0.82      0.77       600
